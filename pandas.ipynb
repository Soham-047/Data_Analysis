# %%
import pandas as pd

# %% [markdown]
# Loading The data

# %%
# Pandas is a cool library for data analysis, manipulation and exploration. In Pandas, we generally use Dataframes and work with tabular data.
# It helps us to explore clean and process data.

# dataframe is a type of tabular format that is used to represent data in tabular form in python. In this we can give names to cols and rows/index.
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=['a', 'b', 'c'], index=['row1', 'row2', 'row3'])
df
# Out:
#       a  b  c
# row1  1  2  3
# row2  4  5  6
# row3  7  8  9

# %%
df.head(1)
# shows us the first 5 rows of the dataframe if number not mentioned.

df.tail(2)
# shows us the last 5 rows of the dataframe if number not mentioned.
# Out:
#       a  b  c
# row2  4  5  6
# row3  7  8  9

# %%
df.index.to_list()
df.index
df.info()

df.nunique()
df['a'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, row1 to row3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# 3

# %%
df.shape
# Out:
# (3, 3)

# %%
df.describe()
# Out:
#          a    b    c
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
coffee = pd.read_csv('warmup_data/coffee.csv')
coffee.head()

#in read_excel(), we also pass another argument such as sheet_name, so as to only get the sheet of the excel file we want.
# Out:
#          Day  Coffee Type   Units Sold Monday   Espresso   25
# 0     Monday        Latte                  15        NaN  NaN
# 1    Tuesday     Espresso                  30        NaN  NaN
# 2    Tuesday        Latte                  20        NaN  NaN
# 3  Wednesday     Espresso                  35        NaN  NaN
# 4  Wednesday        Latte                  25        NaN  NaN

# %% [markdown]
# Accessing the data

# %%
coffee.sample(10, random_state=2)
# Out:
#           Day  Coffee Type   Units Sold Monday   Espresso   25
# 4   Wednesday        Latte                  25        NaN  NaN
# 0      Monday        Latte                  15        NaN  NaN
# 10   Saturday        Latte                  35        NaN  NaN
# 5    Thursday     Espresso                  40        NaN  NaN
# 3   Wednesday     Espresso                  35        NaN  NaN
# 1     Tuesday     Espresso                  30        NaN  NaN
# 9    Saturday     Espresso                  45        NaN  NaN
# 7      Friday     Espresso                  45        NaN  NaN
# 11     Sunday     Espresso                  45        NaN  NaN
# 2     Tuesday        Latte                  20        NaN  NaN

# %% [markdown]
# loc, iloc  -> [rows, cols]
#
# In Pandas, loc and iloc are two fundamental functions used for selecting data from a DataFrame. They differ in how they identify the rows and columns to be selected:
#
# 1. Label-based Indexing (. loc):
#     df. loc [row_label, col_ labell]: Accesses a specific element by its row and column labels.
#     df. loc [row_labels, col_labels] : Selects multiple rows and columns using lists of labels.
#     df. loc [row_labell: Selects an entire row as a Series.
#     df. loc:, col_labell: Selects an entire column as a Series.
#     df. loc [boolean_array]: Filters rows based on a boolean condition applied to a Series or DataFrame.
# 2. Integer-based Indexing (• iloc):
# • df. iloc[row_index, col_indexl: Accesses a specific element by its integer-based row and column positions (0-indexed).
# • df. iloc[row_indices, col_indices]: Selects multiple rows and columns using lists of integer positions.
# • df. iloc [row_index]: Selects an entire row by its integer position.
# • df. iloci:, col_index] : Selects an entire column by its integer position.
# 3. Direct Element Access (• at and ,iat):
# • df. at [row_label, col_label] : Efficiently accesses a single element by label, optimized for single-value retrieval.
# • df. iat [row_index, col_index]: Efficiently accesses a single element by integer position, optimized for single-value retrieval.
# 4. Column Selection (Bracket Notation):
# • df [' column_name']: Selects a single column as a Series.
# • dfI['column_namel', 'column_name2']] : Selects multiple columns as a DataFrame.
# 5. Boolean Indexing:
# • This involves creating a boolean Series or DataFrame based on a condition, then using it with. loc to filter rows. For example, df [df ['Age'] › 30] selects all rows where the 'Age' column is greater than 30.

# %%
coffee.loc[0]
coffee.iloc[0:10] = 10

# %%
coffee.head()
# Out:
#   Day  Coffee Type   Units Sold Monday   Espresso    25
# 0  10           10                  10       10.0  10.0
# 1  10           10                  10       10.0  10.0
# 2  10           10                  10       10.0  10.0
# 3  10           10                  10       10.0  10.0
# 4  10           10                  10       10.0  10.0

# %%
bios = pd.read_csv('warmup_data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# Filtering Data

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] =='FRA')]
# Out:
#         athlete_id            name   born_date   born_city born_region  \
# 82100        82753   Frédéric Weis  1977-06-22  Thionville     Moselle
# 139365      142836  Moustapha Fall  1992-02-23       Paris       Paris
#
#        born_country     NOC  height_cm  weight_kg died_date
# 82100           FRA  France      218.0      110.0       NaN
# 139365          FRA  France      218.0        NaN       NaN

# %%
bios[bios['born_country'].isin(['USA', 'FRA', 'GBR'])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 4                5           Albert Canet  1878-04-17     Wandsworth
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# 1                   Yvelines          FRA         France      183.0
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 3                      Paris          FRA         France      168.0
# 4                    England          GBR         France        NaN
# ...                      ...          ...            ...        ...
# 145454             Wisconsin          USA  United States        NaN
# 145457            California          USA  United States        NaN
# 145467          Hautes-Alpes          FRA          Italy        NaN
# 145468              Michigan          USA  United States      187.0
# 145498           Deux-Sèvres          FRA         France      166.0
#
#         weight_kg   died_date
# 0             NaN  1960-10-02
# 1            76.0         NaN
# 2            76.0  1994-07-17
# 3            64.0  1978-03-20
# 4             NaN  1930-07-25
# ...           ...         ...
# 145454        NaN         NaN
# 145457        NaN         NaN
# 145467        NaN         NaN
# 145468       97.0         NaN
# 145498        NaN  1986-03-18
#
# [20576 rows x 10 columns]

# %%
import numpy as np

# %%
coffee['new price'] = np.where(coffee[' Coffee Type'] == 'Latte', 3.99, 5.59)
coffee_new = coffee

# %%
coffee['new price']
# Out:
# 0     5.59
# 1     5.59
# 2     5.59
# 3     5.59
# 4     5.59
# 5     5.59
# 6     5.59
# 7     5.59
# 8     5.59
# 9     5.59
# 10    5.59
# 11    5.59
# 12    5.59
# Name: new price, dtype: float64

# %%
# coffee.drop(columns=['price'], inplace=True)
# coffee_new.drop(columns=['Day'])
coffee
# Out:
#           Day  Coffee Type   Units Sold Monday   Espresso   25
# 0      Monday        Latte                  15        NaN  NaN
# 1     Tuesday     Espresso                  30        NaN  NaN
# 2     Tuesday        Latte                  20        NaN  NaN
# 3   Wednesday     Espresso                  35        NaN  NaN
# 4   Wednesday        Latte                  25        NaN  NaN
# 5    Thursday     Espresso                  40        NaN  NaN
# 6    Thursday        Latte                  30        NaN  NaN
# 7      Friday     Espresso                  45        NaN  NaN
# 8      Friday        Latte                  35        NaN  NaN
# 9    Saturday     Espresso                  45        NaN  NaN
# 10   Saturday        Latte                  35        NaN  NaN
# 11     Sunday     Espresso                  45        NaN  NaN
# 12     Sunday        Latte                  35        NaN  NaN

# %%
# coffee = coffee[['new price', 'Coffee Type', '25']]
# coffee = coffee[['Day', 'Price']]
coffee['new_price'] = np.where(coffee[" Coffee Type"] != '1', 3.99, 5.59)

# %%
coffee = coffee[['Day', ' Coffee Type', ' Units Sold Monday', 'new_price']]

# %%
coffee
# Out:
#           Day  Coffee Type   Units Sold Monday  new_price
# 0      Monday        Latte                  15       3.99
# 1     Tuesday     Espresso                  30       3.99
# 2     Tuesday        Latte                  20       3.99
# 3   Wednesday     Espresso                  35       3.99
# 4   Wednesday        Latte                  25       3.99
# 5    Thursday     Espresso                  40       3.99
# 6    Thursday        Latte                  30       3.99
# 7      Friday     Espresso                  45       3.99
# 8      Friday        Latte                  35       3.99
# 9    Saturday     Espresso                  45       3.99
# 10   Saturday        Latte                  35       3.99
# 11     Sunday     Espresso                  45       3.99
# 12     Sunday        Latte                  35       3.99

# %%
coffee.rename(columns={' Coffee Type': 'Coffee Type', ' Units Sold Monday': 'Units Sold Monday'}, inplace=True)
# Out:
# /var/folders/h3/pfv58dg11gj_ypdwl4ypvv0r0000gn/T/ipykernel_47105/1483594378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee.rename(columns={' Coffee Type': 'Coffee Type', ' Units Sold Monday': 'Units Sold Monday'}, inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold Monday  new_price
# 0      Monday       Latte                 15       3.99
# 1     Tuesday    Espresso                 30       3.99
# 2     Tuesday       Latte                 20       3.99
# 3   Wednesday    Espresso                 35       3.99
# 4   Wednesday       Latte                 25       3.99
# 5    Thursday    Espresso                 40       3.99
# 6    Thursday       Latte                 30       3.99
# 7      Friday    Espresso                 45       3.99
# 8      Friday       Latte                 35       3.99
# 9    Saturday    Espresso                 45       3.99
# 10   Saturday       Latte                 35       3.99
# 11     Sunday    Espresso                 45       3.99
# 12     Sunday       Latte                 35       3.99

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
bios_new = bios

# %%
bios_new.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
bios_new = bios_new[['name', 'born_date', 'born_city', 'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date']]

# %%
bios_new
# Out:
#                          name   born_date        born_city born_country  \
# 0       Jean-François Blanchy  1886-12-12         Bordeaux          FRA
# 1              Arnaud Boetsch  1969-04-01           Meulan          FRA
# 2                Jean Borotra  1898-08-13         Biarritz          FRA
# 3             Jacques Brugnon  1895-05-11      Paris VIIIe          FRA
# 4                Albert Canet  1878-04-17       Wandsworth          GBR
# ...                       ...         ...              ...          ...
# 145495      Polina Luchnikova  2002-01-30            Serov          RUS
# 145496    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)          RUS
# 145497        Yuliya Smirnova  1998-05-08           Kotlas          RUS
# 145498         André Foussard  1899-05-19            Niort          FRA
# 145499          Bill Phillips  1913-07-15     Dulwich Hill          AUS
#
#               NOC  height_cm  weight_kg   died_date
# 0          France        NaN        NaN  1960-10-02
# 1          France      183.0       76.0         NaN
# 2          France      183.0       76.0  1994-07-17
# 3          France      168.0       64.0  1978-03-20
# 4          France        NaN        NaN  1930-07-25
# ...           ...        ...        ...         ...
# 145495        ROC      167.0       61.0         NaN
# 145496        ROC      168.0       65.0         NaN
# 145497        ROC      163.0       55.0         NaN
# 145498     France      166.0        NaN  1986-03-18
# 145499  Australia        NaN        NaN  2003-10-20
#
# [145500 rows x 8 columns]

# %%
bios_new['first_name'] = bios_new['name'].str.split(" ").str[0]
# Out:
# /var/folders/h3/pfv58dg11gj_ypdwl4ypvv0r0000gn/T/ipykernel_47105/1294443424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_new['first_name'] = bios_new['name'].str.split(" ").str[0]

# %%
bios_new.query('first_name == "Kobe"')
# Out:
#                name   born_date     born_city born_country            NOC  \
# 112365  Kobe Bryant  1978-08-23  Philadelphia          USA  United States
#
#         height_cm  weight_kg   died_date first_name
# 112365      198.0      100.0  2020-01-26       Kobe

# %%
bios_new.info(
    
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          145500 non-null  object
#  1   born_date     143693 non-null  object
#  2   born_city     110908 non-null  object
#  3   born_country  110908 non-null  object
#  4   NOC           145499 non-null  object
#  5   height_cm     106651 non-null  float64
#  6   weight_kg     102070 non-null  float64
#  7   died_date     33940 non-null   object
#  8   first_name    145500 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 10.0+ MB

# %%
bios_new.head()
# Out:
#                     name   born_date    born_city born_country     NOC  \
# 0  Jean-François Blanchy  1886-12-12     Bordeaux          FRA  France
# 1         Arnaud Boetsch  1969-04-01       Meulan          FRA  France
# 2           Jean Borotra  1898-08-13     Biarritz          FRA  France
# 3        Jacques Brugnon  1895-05-11  Paris VIIIe          FRA  France
# 4           Albert Canet  1878-04-17   Wandsworth          GBR  France
#
#    height_cm  weight_kg   died_date     first_name
# 0        NaN        NaN  1960-10-02  Jean-François
# 1      183.0       76.0         NaN         Arnaud
# 2      183.0       76.0  1994-07-17           Jean
# 3      168.0       64.0  1978-03-20        Jacques
# 4        NaN        NaN  1930-07-25         Albert

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'], format="%Y-%m-%d")

# %%
bios_new.drop(columns='born datetime')
# Out:
#                          name   born_date        born_city born_country  \
# 0       Jean-François Blanchy  1886-12-12         Bordeaux          FRA
# 1              Arnaud Boetsch  1969-04-01           Meulan          FRA
# 2                Jean Borotra  1898-08-13         Biarritz          FRA
# 3             Jacques Brugnon  1895-05-11      Paris VIIIe          FRA
# 4                Albert Canet  1878-04-17       Wandsworth          GBR
# ...                       ...         ...              ...          ...
# 145495      Polina Luchnikova  2002-01-30            Serov          RUS
# 145496    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)          RUS
# 145497        Yuliya Smirnova  1998-05-08           Kotlas          RUS
# 145498         André Foussard  1899-05-19            Niort          FRA
# 145499          Bill Phillips  1913-07-15     Dulwich Hill          AUS
#
#               NOC  height_cm  weight_kg   died_date     first_name  \
# 0          France        NaN        NaN  1960-10-02  Jean-François
# 1          France      183.0       76.0         NaN         Arnaud
# 2          France      183.0       76.0  1994-07-17           Jean
# 3          France      168.0       64.0  1978-03-20        Jacques
# 4          France        NaN        NaN  1930-07-25         Albert
# ...           ...        ...        ...         ...            ...
# 145495        ROC      167.0       61.0         NaN         Polina
# 145496        ROC      168.0       65.0         NaN       Valeriya
# 145497        ROC      163.0       55.0         NaN         Yuliya
# 145498     France      166.0        NaN  1986-03-18          André
# 145499  Australia        NaN        NaN  2003-10-20           Bill
#
#        born_datetime
# 0         1886-12-12
# 1         1969-04-01
# 2         1898-08-13
# 3         1895-05-11
# 4         1878-04-17
# ...              ...
# 145495    2002-01-30
# 145496    1999-09-20
# 145497    1998-05-08
# 145498    1899-05-19
# 145499    1913-07-15
#
# [145500 rows x 10 columns]

# %%
bios.to_csv('./warmup_data/bios_new.csv', index= False)

# %%
bios['Height category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 175 else('Average' if x < 190 else 'Tall'))

# %%
# else we could have done 
def height_func(row):
    if row['height_cm'] < 175 and row['weight_kg']:
        return 'Lightweight'
    elif row['height_cm'] < 190 and row['weight_kg']:
        return 'Middleweight'
    else:
        return 'Heavyweight'
# axis=1  is for rows, for columns is for 0
bios["BMI Category"] = bios.apply(height_func, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date Height category  BMI Category
# 0  1960-10-02            Tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20           Short   Lightweight
# 4  1930-07-25            Tall   Heavyweight

# %% [markdown]
# Merging and concatenating data

# %%
noc = pd.read_csv('./warmup_data/noc_regions.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date Height category  BMI Category
# 0       1960-10-02            Tall   Heavyweight
# 1              NaN         Average  Middleweight
# 2       1994-07-17         Average  Middleweight
# 3       1978-03-20           Short   Lightweight
# 4       1930-07-25            Tall   Heavyweight
# ...            ...             ...           ...
# 145495         NaN           Short   Lightweight
# 145496         NaN           Short   Lightweight
# 145497         NaN           Short   Lightweight
# 145498  1986-03-18           Short   Lightweight
# 145499  2003-10-20            Tall   Heavyweight
#
# [145500 rows x 12 columns]

# %%
noc.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, noc, left_on='born_country', right_on='NOC', how='inner')

# %%
bios_new.drop(columns='born_country', inplace=True)

# %%
bios_new.rename(columns={'region': 'born_country'})
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 110634      149222      Polina Luchnikova  2002-01-30            Serov
# 110635      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 110636      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 110637      149225         André Foussard  1899-05-19            Niort
# 110638      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 110634            Sverdlovsk          RUS        ROC      167.0       61.0
# 110635                Moskva          RUS        ROC      168.0       65.0
# 110636           Arkhangelsk          RUS        ROC      163.0       55.0
# 110637           Deux-Sèvres          FRA     France      166.0        NaN
# 110638       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date Height category  BMI Category NOC_y born_country notes
# 0       1960-10-02            Tall   Heavyweight   FRA       France   NaN
# 1              NaN         Average  Middleweight   FRA       France   NaN
# 2       1994-07-17         Average  Middleweight   FRA       France   NaN
# 3       1978-03-20           Short   Lightweight   FRA       France   NaN
# 4       1930-07-25            Tall   Heavyweight   GBR           UK   NaN
# ...            ...             ...           ...   ...          ...   ...
# 110634         NaN           Short   Lightweight   RUS       Russia   NaN
# 110635         NaN           Short   Lightweight   RUS       Russia   NaN
# 110636         NaN           Short   Lightweight   RUS       Russia   NaN
# 110637  1986-03-18           Short   Lightweight   FRA       France   NaN
# 110638  2003-10-20            Tall   Heavyweight   AUS    Australia   NaN
#
# [110639 rows x 15 columns]

# %%
bios_new.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region', 'NOC_x',
#        'height_cm', 'weight_kg', 'died_date', 'Height category',
#        'BMI Category', 'NOC_y', 'region', 'notes'],
#       dtype='object')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region   NOC_x  height_cm  weight_kg   died_date  \
# 0               Gironde  France        NaN        NaN  1960-10-02
# 1              Yvelines  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques  France      183.0       76.0  1994-07-17
# 3                 Paris  France      168.0       64.0  1978-03-20
# 4               England  France        NaN        NaN  1930-07-25
#
#   Height category  BMI Category NOC_y  region notes
# 0            Tall   Heavyweight   FRA  France   NaN
# 1         Average  Middleweight   FRA  France   NaN
# 2         Average  Middleweight   FRA  France   NaN
# 3           Short   Lightweight   FRA  France   NaN
# 4            Tall   Heavyweight   GBR      UK   NaN

# %%
bios_new.rename(columns={'region': 'born_country'}, inplace=True)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region   NOC_x  height_cm  weight_kg   died_date  \
# 0               Gironde  France        NaN        NaN  1960-10-02
# 1              Yvelines  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques  France      183.0       76.0  1994-07-17
# 3                 Paris  France      168.0       64.0  1978-03-20
# 4               England  France        NaN        NaN  1930-07-25
#
#   Height category  BMI Category NOC_y born_country notes
# 0            Tall   Heavyweight   FRA       France   NaN
# 1         Average  Middleweight   FRA       France   NaN
# 2         Average  Middleweight   FRA       France   NaN
# 3           Short   Lightweight   FRA       France   NaN
# 4            Tall   Heavyweight   GBR           UK   NaN

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country']][['name', 'NOC_x', 'born_country']]
# Out:
#                        name                NOC_x born_country
# 4              Albert Canet               France           UK
# 14               Guy Forget               France      Morocco
# 32          Helen Aitchison        Great Britain           UK
# 33        Geraldine Beamish        Great Britain           UK
# 34             Dora Boothby        Great Britain           UK
# ...                     ...                  ...          ...
# 110630         Shakeel John  Trinidad and Tobago     Trinidad
# 110632   Landysh Falyakhova                  ROC       Russia
# 110634    Polina Luchnikova                  ROC       Russia
# 110635  Valeriya Merkusheva                  ROC       Russia
# 110636      Yuliya Smirnova                  ROC       Russia
#
# [38349 rows x 3 columns]

# %%
usa = bios_new[bios_new['born_country'] == 'USA'].copy()

# %%
gbr = bios_new[bios_new['born_country'] == 'France'].copy()

# %%
bios_new[bios_new['born_country'] == 'France'].head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5           6      Nicolas Chatelain  1970-01-13       Amiens
#
#             born_region   NOC_x  height_cm  weight_kg   died_date  \
# 0               Gironde  France        NaN        NaN  1960-10-02
# 1              Yvelines  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques  France      183.0       76.0  1994-07-17
# 3                 Paris  France      168.0       64.0  1978-03-20
# 5                 Somme  France      181.0       70.0         NaN
#
#   Height category  BMI Category NOC_y born_country notes
# 0            Tall   Heavyweight   FRA       France   NaN
# 1         Average  Middleweight   FRA       France   NaN
# 2         Average  Middleweight   FRA       France   NaN
# 3           Short   Lightweight   FRA       France   NaN
# 5         Average  Middleweight   FRA       France   NaN

# %%
gbr.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5           6      Nicolas Chatelain  1970-01-13       Amiens
#
#             born_region   NOC_x  height_cm  weight_kg   died_date  \
# 0               Gironde  France        NaN        NaN  1960-10-02
# 1              Yvelines  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques  France      183.0       76.0  1994-07-17
# 3                 Paris  France      168.0       64.0  1978-03-20
# 5                 Somme  France      181.0       70.0         NaN
#
#   Height category  BMI Category NOC_y born_country notes
# 0            Tall   Heavyweight   FRA       France   NaN
# 1         Average  Middleweight   FRA       France   NaN
# 2         Average  Middleweight   FRA       France   NaN
# 3           Short   Lightweight   FRA       France   NaN
# 5         Average  Middleweight   FRA       France   NaN

# %%
new_df = pd.concat([usa, gbr])

# %%
new_df.sample(10)
# Out:
#        athlete_id                    name   born_date     born_city  \
# 33910       46901          Jérôme Nalliod  1966-07-29          Lyon
# 80341      109562         Kristen Caverly  1984-09-20  San Clemente
# 3676         5327         Janice Lawrence  1962-06-07      Lucedale
# 68987       95459             Jack Miller  1965-03-20       Boulder
# 55236       77753    Sharrieffa Barksdale  1961-02-18      Harriman
# 75264      103117             M'fon Udoka  1976-06-16      Portland
# 36821       51087           Nicole Kramer  1962-02-08        Quincy
# 58490       82110           Kriste Porter  1971-09-03        Biloxi
# 21971       29888         Alfred Bruyenne  1892-04-08         Lille
# 32177       44582  Nancy Napolski-Johnson  1974-01-14   Phenix City
#
#        born_region          NOC_x  height_cm  weight_kg   died_date  \
# 33910        Rhône         France      178.0       72.0         NaN
# 80341   California  United States      177.0       63.0         NaN
# 3676   Mississippi  United States      190.0       73.0         NaN
# 68987     Colorado  United States        NaN        NaN         NaN
# 55236    Tennessee  United States      162.0       54.0         NaN
# 75264       Oregon        Nigeria      188.0       84.0         NaN
# 36821     Illinois  United States      153.0       50.0         NaN
# 58490  Mississippi  United States      167.0       65.0         NaN
# 21971         Nord         France        NaN        NaN  1962-11-10
# 32177      Alabama  United States      157.0       56.0         NaN
#
#       Height category  BMI Category NOC_y born_country notes
# 33910         Average  Middleweight   FRA       France   NaN
# 80341         Average  Middleweight   USA          USA   NaN
# 3676             Tall   Heavyweight   USA          USA   NaN
# 68987            Tall   Heavyweight   USA          USA   NaN
# 55236           Short   Lightweight   USA          USA   NaN
# 75264         Average  Middleweight   USA          USA   NaN
# 36821           Short   Lightweight   USA          USA   NaN
# 58490           Short   Lightweight   USA          USA   NaN
# 21971            Tall   Heavyweight   FRA       France   NaN
# 32177           Short   Lightweight   USA          USA   NaN

# %%
results = pd.read_csv('warmup_data/results.csv')

# %%
merge_df = pd.merge(results, bios_new, left_on='athlete_id', right_on='athlete_id', how='left')

# %%
merge_df.sample(10)
# Out:
#           year    type                           discipline  \
# 217800  2002.0  Winter              Speed Skating (Skating)
# 86519   1968.0  Summer                               Rowing
# 187231  1992.0  Winter                Bobsleigh (Bobsleigh)
# 236155  2006.0  Winter                             Biathlon
# 282620  2016.0  Summer              Cycling Track (Cycling)
# 43778   1936.0  Summer                              Fencing
# 16097   1996.0  Summer              Canoe Sprint (Canoeing)
# 258638  2010.0  Winter  Short Track Speed Skating (Skating)
# 243116  2012.0  Summer                  Swimming (Aquatics)
# 284301  2016.0  Summer     Artistic Gymnastics (Gymnastics)
#
#                                                   event                    as  \
# 217800                    1,500 metres, Women (Olympic)         Cindy Klassen
# 86519                      Double Sculls, Men (Olympic)            Bill Maher
# 187231                               Two, Men (Olympic)     Dragiša Jovanović
# 236155              10 kilometres Sprint, Men (Olympic)    Sebastián Beltrame
# 282620                            Omnium, Men (Olympic)       Jasper De Buyst
# 43778                   Foil, Individual, Men (Olympic)        Nils Jørgensen
# 16097     Canadian Doubles, 1,000 metres, Men (Olympic)  Kaysar Nurmaganbetov
# 258638                5,000 metres Relay, Men (Olympic)             Simon Cho
# 243116  4 × 200 metres Freestyle Relay, Women (Olympic)               Tang Yi
# 284301                    Horizontal Bar, Men (Olympic)          Oskar Kirmes
#
#         athlete_id  noc                        team  place   tied  ...  \
# 217800      100967  CAN                         NaN    4.0  False  ...
# 86519        40766  USA                   John Nunn    3.0  False  ...
# 187231       87654  YUG            Ognjen Sokolović   34.0  False  ...
# 236155      109619  ARG                         NaN   86.0  False  ...
# 282620      132665  BEL                         NaN    NaN  False  ...
# 43778        23015  NOR                         NaN    7.0  False  ...
# 16097        10257  KAZ             Sergey Sergeyev    4.0  False  ...
# 258638      119801  USA               United States    3.0  False  ...
# 243116      112313  CHN  People's Republic of China    6.0  False  ...
# 284301      133790  FIN                         NaN   64.0  False  ...
#
#              born_region                       NOC_x height_cm weight_kg  \
# 217800          Manitoba                      Canada     173.0      71.0
# 86519           Michigan               United States     186.0      86.0
# 187231               NaN                         NaN       NaN       NaN
# 236155               NaN                         NaN       NaN       NaN
# 282620    Vlaams Brabant                     Belgium     178.0      69.0
# 43778               Oslo                      Norway       NaN       NaN
# 16097        Quaraghandy                  Kazakhstan     185.0      78.0
# 258638             Seoul               United States     183.0      68.0
# 243116          Shanghai  People's Republic of China     178.0      70.0
# 284301  Höfuðborgarsvæði                     Finland     170.0      62.0
#
#          died_date Height category  BMI Category  NOC_y born_country notes
# 217800         NaN           Short   Lightweight    CAN       Canada   NaN
# 86519          NaN         Average  Middleweight    USA          USA   NaN
# 187231         NaN             NaN           NaN    NaN          NaN   NaN
# 236155         NaN             NaN           NaN    NaN          NaN   NaN
# 282620         NaN         Average  Middleweight    BEL      Belgium   NaN
# 43778   1996-01-15            Tall   Heavyweight    NOR       Norway   NaN
# 16097          NaN         Average  Middleweight    KAZ   Kazakhstan   NaN
# 258638         NaN         Average  Middleweight    KOR  South Korea   NaN
# 243116         NaN         Average  Middleweight    CHN        China   NaN
# 284301         NaN           Short   Lightweight    ISL      Iceland   NaN
#
# [10 rows x 24 columns]

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().tail(25)
# Out:
# born_region
# Utah              91
# Missouri          91
# North Carolina    86
# Arizona           83
# New Hampshire     83
# Vermont           68
# Mississippi       66
# Alabama           64
# Kentucky          62
# Tennessee         62
# Nebraska          60
# Rhode Island      56
# Montana           55
# South Carolina    50
# Maine             50
# Alaska            45
# Arkansas          42
# Idaho             41
# New Mexico        38
# Nevada            36
# South Dakota      27
# West Virginia     24
# Delaware          22
# North Dakota      16
# Wyoming           14
# Name: count, dtype: int64

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold Monday', 'new_price'], dtype='object')

# %% [markdown]
# AGGREGATE DATA

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold Monday': 'sum', 'new_price': 'mean'})
# Out:
#              Units Sold Monday  new_price
# Coffee Type
# Espresso                   240       3.99
# Latte                      195       3.99

# %% [markdown]
# Easy wasy to work with long data is to make pivots

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='Units Sold Monday')

# %%
pivot
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday           45.0   35.0
# Monday            NaN   15.0
# Saturday         45.0   35.0
# Sunday           45.0   35.0
# Thursday         40.0   30.0
# Tuesday          30.0   20.0
# Wednesday        35.0   25.0

# %%
pivot.loc['Friday', ' Latte']
pivot.sum(axis = 1)
# Out:
# Day
# Friday       80.0
# Monday       15.0
# Saturday     80.0
# Sunday       80.0
# Thursday     70.0
# Tuesday      50.0
# Wednesday    60.0
# dtype: float64

# %% [markdown]
# import numpy as np

# %%
import numpy as np

# %%
# %%timeit
temp = pd.array([1, 2, 3, 4, 5, 6, 7, 8, ])
# Out:
# 14.3 μs ± 123 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
t1 = np.array([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 755 ns ± 11.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np
import matplotlib.pyplot as plt
def mandelbrot(h, w, maxit=20, r=2):
    """Returns an image of the Mandelbrot fractal of size (h,w)."""
    x = np.linspace(-2.5, 1.5, 4*h+1)
    y = np.linspace(-1.5, 1.5, 3*w+1)
    A, B = np.meshgrid(x, y)
    C = A + B*1j
    z = np.zeros_like(C)
    divtime = maxit + np.zeros(z.shape, dtype=int)

    for i in range(maxit):
        z = z**2 + C
        diverge = abs(z) > r # who is diverging
        div_now = diverge & (divtime == maxit) # who is diverging now
        divtime[div_now] = i # note when
        z[diverge] = r # avoid diverging too much

    return divtime
plt.clf()
plt.imshow(mandelbrot(400, 400))
# Out:
# Matplotlib is building the font cache; this may take a moment.
